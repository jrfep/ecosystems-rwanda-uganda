# %% [markdown]
# We start importing the libraries we need.

# %%
from datetime import datetime, timedelta

import ipyplot
from dateutil.relativedelta import relativedelta
from IPython.display import Image
from pyinaturalist import (
    ICONIC_TAXA,
    Observation,
    TaxonCount,
    UserCount,
    enable_logging,
    get_observation_histogram,
    get_observation_identifiers,
    get_observation_observers,
    get_observation_species_counts,
    get_observations,
    pprint,
)
from rich import print

enable_logging()

# %%
import folium
import pandas as pd

# %%
def popup_html(df,row):
    name=df['taxon'].iloc[row] 
    place=df['place'].iloc[row] 
    url=df['url'].iloc[row]
    
    if df['EFG'].iloc[row] is None:
        html = """<!DOCTYPE html>
<html>
<head>
<h4 style="margin-bottom:10"; width="200px">{taxon}</h4>
</head>
<a href='{url}' target='inat'>iNat page</a>
    <table style="height: 126px; width: 200px;">
<tbody>
<tr>
<td style="background-color: {color1};"><span style="color: #ffffff;">Place</span></td>
<td style="width: 60%;background-color: {color2};">{place}</td>
</tr>
<tr>
<td style="background-color: {color1};"><span style="color: #ffffff;">Taxon</span></td>
<td style="width: 60%;background-color: {color2};">{taxon}</td>
</tr>
</tbody>
</table>
<span>{message}</span>
</html>
"""
        if df['has_context'].iloc[row] is None:
            message='This observation needs to be reviewed'
        elif df['has_context'].iloc[row] is True:
            message='This observation has been reviewed but some information is missing'
        else:
            message='This observation has been reviewed but does not have enough context to assign a Ecosystem Functional Group'
        
        output=html.format(taxon=name,place=place,url=url,EFG=None,comment=None,
                           color1="#a9a7bd",color2="#d2d0d3",message=message)

    else:
        efg=df['EFG'].iloc[row]
        comment=df['comment'].iloc[row]
    
        html = """<!DOCTYPE html>
<html>
<head>
<h4 style="margin-bottom:10"; width="200px">{taxon}</h4>
</head>
<a href='{url}' target='inat'>iNat page</a>
    <table style="height: 126px; width: 300px;">
<tbody>
<tr>
<td style="background-color: {color1};"><span style="color: #ffffff;">Place</span></td>
<td style="width: 60%;background-color: {color2};">{place}</td>
</tr>
<tr>
<td style="background-color: {color1};"><span style="color: #ffffff;">Taxon</span></td>
<td style="width: 60%;background-color: {color2};">{taxon}</td>
</tr>
<tr>
<td style="background-color: {color1};"><span style="color: #ffffff;">EFG</span></td>
<td style="width: 60%;background-color: {color2};">{EFG}</td>
</tr>
<tr>
<td style="background-color: {color1};"><span style="color: #ffffff;">Comment</span></td>
<td style="width: 60%;background-color: {color2};">{comment}</td>
</tr>
</tbody>
</table>
</html>
"""
        output=html.format(taxon=name,place=place,url=url,EFG=efg,comment=comment,color1="#19a7bd",color2="#f2f0d3")
        
    return output

# %%
tids = [48039, # Lobelias
        68790, # Gorillas
        341182 # Dendrosenecio
       ]
#tids = 341182
response=get_observations(place_id=7142, taxon_id=tids, page='all')
qry_observations = Observation.from_json_list(response)
# Out:
# [04-20 14:40:07] INFO     Request:                                                                   ]8;id=667057;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/session.py\session.py]8;;\:]8;id=127512;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/session.py#250\250]8;;\
#                           GET
#                           https://api.inaturalist.org/v1/observations?taxon_id=48039%2C68790%2C34118
#                           2&place_id=7142&only_id=false&per_page=200&order_by=id&order=asc
#                           User-Agent: python-requests/2.28.2 pyinaturalist/0.18.0
#                           Accept-Encoding: gzip, deflate
#                           Accept: application/json
#                           Connection: keep-alive
# [04-20 14:40:13] INFO     This query will fetch 224 results in 2 requests. Estimated total request ]8;id=659570;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/paginator.py\paginator.py]8;;\:]8;id=333163;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/paginator.py#198\198]8;;\
#                           time: 1 seconds
#                  INFO     Request:                                                                   ]8;id=15074;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/session.py\session.py]8;;\:]8;id=204400;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/session.py#250\250]8;;\
#                           GET
#                           https://api.inaturalist.org/v1/observations?taxon_id=48039%2C68790%2C34118
#                           2&place_id=7142&only_id=false&id_above=130761538&per_page=200&order_by=id&
#                           order=asc
#                           User-Agent: python-requests/2.28.2 pyinaturalist/0.18.0
#                           Accept-Encoding: gzip, deflate
#                           Accept: application/json
#                           Connection: keep-alive

# %%
source = pd.DataFrame(
    [
        {
            'latitude': o.location[0],
            'longitude': o.location[1],
            'id':o.id,
            'url':o.uri,
            'place':o.place_guess,
            'taxon':o.species_guess,
            'iconic_taxon': o.taxon.iconic_taxon_name,
            'has_context':None,
            'reviewer':None,
            'EFG':None,
            'confidence':None,
            'comment':None,
        }
        for o in qry_observations
        if o.location
    ]
)

# %%
source.shape
# Out:
# (224, 12)

# %%
source.tail()
# Out:
#      latitude  longitude         id
# 219 -2.477868  29.226256  143936748  \
# 220 -1.437719  29.795246  144164246
# 221 -2.462299  29.246248  144463557
# 222 -2.440879  29.252687  144463734
# 223 -1.508119  29.419630  150942853
#
#                                                    url                  place
# 219  https://www.inaturalist.org/observations/14393...     Iburengerazuba, RW  \
# 220  https://www.inaturalist.org/observations/14416...                 Rwanda
# 221  https://www.inaturalist.org/observations/14446...  Nyamasheke, RW-OU, RW
# 222  https://www.inaturalist.org/observations/14446...  Nyamasheke, RW-OU, RW
# 223  https://www.inaturalist.org/observations/15094...                 Rwanda
#
#                          taxon iconic_taxon has_context reviewer   EFG
# 219                       None      Plantae        None     None  None  \
# 220           Mountain Gorilla     Mammalia        None     None  None
# 221          Lobelia petiolata      Plantae        None     None  None
# 222           Lobelia giberroa      Plantae        None     None  None
# 223  Gorilla beringei beringei     Mammalia        None     None  None
#
#     confidence comment
# 219       None    None
# 220       None    None
# 221       None    None
# 222       None    None
# 223       None    None

# %%
 # initialize the map and store it in a m object
m = folium.Map(location = [-2, 29.5],
               zoom_start = 8)

# %%
locations = source[['latitude', 'longitude']]
locationlist = locations.values.tolist()

# %%
for point in range(0, len(locationlist)):
    context=source['has_context'].iloc[point]
    if context is None:
        color = 'gray'
    elif context is True:
        color = 'darkblue'
    else:
        color = 'lightred'
    folium.Marker(locationlist[point], icon=folium.Icon(color=color), popup=popup_html(source,point)).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_023ac76cbff0b9e8e6b26de5771e7571 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_023ac76cbff0b9e8e6b26de5771e7571&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_023ac76cbff0b9e8e6b26de5771e7571 = L.map(
#                 &quot;map_023ac76cbff0b9e8e6b26de5771e7571&quot;,
#                 {
#                     center: [-2.0, 29.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b54c4184da015f02e1112b9c6c474ec5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_023ac76cbff0b9e8e6b26de5771e7571);
#
#
#             var marker_d52f8e666bfbce8e6e79200778e18392 = L.marker(
#                 [-1.4318240565, 29.5781571468],
#                 {}
#             ).addTo(map_023ac76cbff0b9e8e6b26de5771e7571);
#
#
#             var icon_1d67985c0176f7b50e451c1025edeae1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d52f8e666bfbce8e6e79200778e18392.setIcon(icon_1d67985c0176f7b50e451c1025edeae1);
#
#
#         var popup_c021ea62e5959cb9cd3ef567545cba56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2e7d520ea335e8b0011d900dd88567f = $(`&lt;div id=&quot;html_c2e7d520ea335e8b0011d900dd88567f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt; &lt;html&gt; &lt;head&gt; &lt;h4 style=&quot;margin-bottom:10&quot;; width=&quot;200px&quot;&gt;Gorilla beringei beringei&lt;/h4&gt; &lt;/head&gt; &lt;a href=&#x27;http://www.inaturalist.org/observations/1719286&#x27; target=&#x27;inat&#x27;&gt;iNat page&lt;/a&gt;     &lt;table style=&quot;height: 126px; width: 200px;&quot;&gt; &lt;tbody&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Place&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;Rwanda&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Taxon&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;Gorilla beringei beringei&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt; &lt;span&gt;This observation needs to be reviewed&lt;/span&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_c021ea62e5959cb9cd3ef567545cba56.setContent(html_c2e7d520ea335e8b0011d900dd88567f);
#
#
#
#         marker_d52f8e666bfbce8e6e79200778e18392.bindPopup(popup_c021ea62e5959cb9cd3ef567545cba56)
#         ;
#
#
#
#
#             var marker_65fd70a853c11485d098918dbed6ad93 = L.marker(
#                 [-1.8503425455, 29.5341874432],
#                 {}
#             ).addTo(map_023ac76cbff0b9e8e6b26de5771e7571);
#
#
#             var icon_dcf7c517666f75bff37ff1a0634ea75d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_65fd70a853c11485d098918dbed6ad93.setIcon(icon_dcf7c517666f75bff37ff1a0634ea75d);
#
#
#         var popup_eeef7c0cb2849c55f08cdcd2b378cccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b27aa0c32a2177444fa7750524b6797 = $(`&lt;div id=&quot;html_3b27aa0c32a2177444fa7750524b6797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt; &lt;html&gt; &lt;head&gt; &lt;h4 style=&quot;margin-bottom:10&quot;; width=&quot;200px&quot;&gt;Mountain Gorilla&lt;/h4&gt; &lt;/head&gt; &lt;a href=&#x27;http://www.inaturalist.org/observations/3061470&#x27; target=&#x27;inat&#x27;&gt;iNat page&lt;/a&gt;     &lt;table style=&quot;height: 126px; width: 200px;&quot;&gt; &lt;tbody&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Place&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;Rwanda&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Taxon&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;Mountain Gorilla&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt; &lt;span&gt;This observation needs to be reviewed&lt;/span&gt; &lt

# %%
def evaluateContext(rid,context=None,validcoords=None):
    if context is None:
        input(...)

# %%
len(locationlist)
# Out:
# 14

# %% [markdown]
# Another example for plants from the Grazing guidelines for Gayini.

# %%
pids = [49025]
tids = [502254, # Eucalyptus largiflorens # Black Box
        122825, # Acacia victoriae # Bramble Wattle
        52795, # Hordeum leporinum
        934705, # Maireana pyramidata
        291217, # Acacia salicina
        288066# Lachagrostis filiformis
    ]

response=get_observations(place_id=pids, taxon_id=tids, page='all')
qry_observations = Observation.from_json_list(response)
# Out:
# [04-20 14:35:25] INFO     Request:                                                                   ]8;id=206043;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/session.py\session.py]8;;\:]8;id=958290;file:///home/jferrer/proyectos/venv/ee/lib/python3.10/site-packages/pyinaturalist/session.py#250\250]8;;\
#                           GET
#                           https://api.inaturalist.org/v1/observations?taxon_id=502254%2C122825%2C527
#                           95%2C934705%2C291217%2C288066&place_id=49025&only_id=false&per_page=200&or
#                           der_by=id&order=asc
#                           User-Agent: python-requests/2.28.2 pyinaturalist/0.18.0
#                           Accept-Encoding: gzip, deflate
#                           Accept: application/json
#                           Connection: keep-alive

# %%
source = pd.DataFrame(
    [
        {
            'latitude': o.location[0],
            'longitude': o.location[1],
            'id':o.id,
            'url':o.uri,
            'place':o.place_guess,
            'taxon':o.species_guess,
            'iconic_taxon': o.taxon.iconic_taxon_name,
            'has_context':None,
            'reviewer':None,
            'EFG':None,
            'confidence':None,
            'comment':None,
        }
        for o in qry_observations
        if o.location
    ]
)

# %%
source.tail()
# Out:
#     latitude   longitude         id
# 0 -34.430124  144.842637   47704600  \
# 1 -34.516033  144.843674   47704610
# 2 -34.239554  144.376457  131295113
# 3 -34.511721  144.834677  143704027
#
#                                                  url
# 0  https://www.inaturalist.org/observations/47704600  \
# 1  https://www.inaturalist.org/observations/47704610
# 2  https://www.inaturalist.org/observations/13129...
# 3  https://www.inaturalist.org/observations/14370...
#
#                        place      taxon iconic_taxon has_context reviewer
# 0             Hay, AU-NS, AU       None      Plantae        None     None  \
# 1             Hay, AU-NS, AU       None      Plantae        None     None
# 2  Maude NSW 2711, Australia  Black Box      Plantae        None     None
# 3    Hay NSW 2711, Australia  Black Box      Plantae        None     None
#
#     EFG confidence comment
# 0  None       None    None
# 1  None       None    None
# 2  None       None    None
# 3  None       None    None

# %%
 # initialize the map and store it in a m object
m = folium.Map(location = [-34, 144],
               zoom_start = 8)
locations = source[['latitude', 'longitude']]
locationlist = locations.values.tolist()
for point in range(0, len(locationlist)):
    context=source['has_context'].iloc[point]
    if context is None:
        color = 'gray'
    elif context is True:
        color = 'darkblue'
    else:
        color = 'lightred'
    folium.Marker(locationlist[point], icon=folium.Icon(color=color), popup=popup_html(source,point)).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27704841fb68e74a296488153d12d21d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27704841fb68e74a296488153d12d21d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27704841fb68e74a296488153d12d21d = L.map(
#                 &quot;map_27704841fb68e74a296488153d12d21d&quot;,
#                 {
#                     center: [-34.0, 144.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b349d94a48a544c9f4ab6df6fa5122d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_27704841fb68e74a296488153d12d21d);
#
#
#             var marker_8729eaeeb2ed7cd04b58f882ac4c6eba = L.marker(
#                 [-34.430124, 144.842637],
#                 {}
#             ).addTo(map_27704841fb68e74a296488153d12d21d);
#
#
#             var icon_eb6db188a7f5e29f5953e623fa3724ab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8729eaeeb2ed7cd04b58f882ac4c6eba.setIcon(icon_eb6db188a7f5e29f5953e623fa3724ab);
#
#
#         var popup_b77b91a729905e1805ab34bf0786189a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_772c4b4aa90b3ff24a0e08b2b12663c7 = $(`&lt;div id=&quot;html_772c4b4aa90b3ff24a0e08b2b12663c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt; &lt;html&gt; &lt;head&gt; &lt;h4 style=&quot;margin-bottom:10&quot;; width=&quot;200px&quot;&gt;None&lt;/h4&gt; &lt;/head&gt; &lt;a href=&#x27;https://www.inaturalist.org/observations/47704600&#x27; target=&#x27;inat&#x27;&gt;iNat page&lt;/a&gt;     &lt;table style=&quot;height: 126px; width: 200px;&quot;&gt; &lt;tbody&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Place&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;Hay, AU-NS, AU&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Taxon&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;None&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt; &lt;span&gt;This observation needs to be reviewed&lt;/span&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_b77b91a729905e1805ab34bf0786189a.setContent(html_772c4b4aa90b3ff24a0e08b2b12663c7);
#
#
#
#         marker_8729eaeeb2ed7cd04b58f882ac4c6eba.bindPopup(popup_b77b91a729905e1805ab34bf0786189a)
#         ;
#
#
#
#
#             var marker_0610e7dcd5873ef3175518cce9c63914 = L.marker(
#                 [-34.516033, 144.843674],
#                 {}
#             ).addTo(map_27704841fb68e74a296488153d12d21d);
#
#
#             var icon_3a0d522e396599db42673438e87df329 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0610e7dcd5873ef3175518cce9c63914.setIcon(icon_3a0d522e396599db42673438e87df329);
#
#
#         var popup_b6171af80172b45ce4830de1759a76fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_918bbdfd5b0d094a6e02ad207e95c862 = $(`&lt;div id=&quot;html_918bbdfd5b0d094a6e02ad207e95c862&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt; &lt;html&gt; &lt;head&gt; &lt;h4 style=&quot;margin-bottom:10&quot;; width=&quot;200px&quot;&gt;None&lt;/h4&gt; &lt;/head&gt; &lt;a href=&#x27;https://www.inaturalist.org/observations/47704610&#x27; target=&#x27;inat&#x27;&gt;iNat page&lt;/a&gt;     &lt;table style=&quot;height: 126px; width: 200px;&quot;&gt; &lt;tbody&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Place&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;Hay, AU-NS, AU&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #a9a7bd;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Taxon&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 60%;background-color: #d2d0d3;&quot;&gt;None&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt; &lt;span&gt;This observation needs to be reviewed&lt;/span&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_b617
